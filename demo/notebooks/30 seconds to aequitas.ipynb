# %% [markdown]
# # ***THIS IS AN OUTLINE ***

# %% [markdown]
# # aequitas: detecting bias in machine learning
#
# [Try it now](https://jzo5v1.axshare.com/home.html)
# or
# [Install on your computer](https://github.com/dssg/aequitas-public)
#
# < Welcome language / Descriptions >
#
# Read the documentation at [documentation]().
#
# Aequitas is compatible with: __Python X.X__.
#
#
# ------------------

# %% [markdown]
# # The first 30 seconds:
#
# - < Problem Description > Where is the bias?
# - With aequitas it's as simple as running a single command on a csv.

# %% [markdown]
# ```bash
# $ python3 aequitas-audit --input compas_for_aequitas.csv
# ```

# %% [markdown]
# ### Input machine learning predictions
# The input data at least has:
# - score
# - label_value
# - group columns: race, sex
# - ***entity id doesn't seem necessary. is it required?***
# [more information on input data](input_data)
#
# Additionally, disparity is always defined in relation to a base group. We provide several ways to define a base group.
# [Defining a base group](base_groups)
#
# < mention SQL query as input ? >

# %%
df = pd.read_csv('../data/compas_for_aequitas.csv')
df.head()
# Out:
#    entity_id  score  label_value              race   sex       age_cat
# 0       2793    1.0            0  African-American  Male       25 - 45
# 1       7338    1.0            1  African-American  Male  Less than 25
# 2      10512    1.0            1  African-American  Male       25 - 45
# 3       3816    1.0            1             Other  Male  Less than 25
# 4       8933    1.0            1         Caucasian  Male       25 - 45

# %% [markdown]
# ### Get out measures of bias that you can tailor to your problem
#
# #### Bias report
#
# < PDF >
#
# #### Bias metrics table
# The bias metrics table includes measures of bias and disparity that you can learn more about here: [understanding output]()

# %%
df = pd.read_csv('../data/compas_group_value_fairness.csv')
df.drop(df.columns[0], axis=1).head()
# Out:
#         TPR       group_value group_variable     k  model_id parameter  \
# 0  0.720147  African-American           race  3317         1  3317_abs
# 1  0.666667             Asian           race  3317         1  3317_abs
# 2  0.522774         Caucasian           race  3317         1  3317_abs
# 3  0.443966          Hispanic           race  3317         1  3317_abs
# 4  0.900000   Native American           race  3317         1  3317_abs
#
#         TNR      FOmR       FDR       FPR       FNR       NPV  Precision  \
# 0  0.551532  0.349540  0.370285  0.448468  0.279853  0.650460   0.629715
# 1  0.913043  0.125000  0.250000  0.086957  0.333333  0.875000   0.750000
# 2  0.765457  0.288125  0.408665  0.234543  0.477226  0.711875   0.591335
# 3  0.785185  0.288591  0.457895  0.214815  0.556034  0.711409   0.542105
# 4  0.625000  0.166667  0.250000  0.375000  0.100000  0.833333   0.750000
#
#      PP    PN       PPR     PPrev   FP   FN    TN    TP  group_label_neg  \
# ...

# %% [markdown]
# The software can be used on several competing models [using more models]()
#
# ---

# %% [markdown]
# ________
# # Installation
#
# Aequitas is an extension to pandas. To use you need python installed along with the XXX packages.
#
#
# ### install from the GitHub source:
#
# First, clone aequitas using `git`:
#
# ```python
# git clone https://github.com/dssg/aequitas-public.git
# ```
#
# Now `cd` and run the software:
#
# ```python
# # how do we expect users to run the software?
# ```

# %%
import pandas as pd

# %%
pd.options.display.max_columns = 100
