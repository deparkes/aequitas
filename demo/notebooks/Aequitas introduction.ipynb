# %% [markdown]
# # Aequitas Introduction
#
# Practitioners face the challenge of determining whether or not such patterns reflect bias or not. The fact that we have multiple ways to measure bias adds complexity to the decisionmaking process. With Aequitas, we provide a tool that automates the reporting of various fairnes metrics to aid in this process.
#
# In this introduction, we provide a highlevel overview of the bias reports output by Aequitas.

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
def color_tf(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    if val == True:
        color = 'green'
    elif val == False:
        color = 'red'
    else:
        color = ''
    return 'color: %s' % color

# %%
df = pd.read_csv('../data/aequinas_test_20180223.csv')

# %% [markdown]
# ### Input data
#
# You input a csv using the command-line function `aequitas_audit`. The csv has columns for `entity_id`, `score`, and `label_value` as well as group attributes against which to test for disparities. In this cases we include `race`, `sex` and `age_cat`.

# %%
df[['model_id', 'entity_id', 'score', 'label_value','race', 'gender', 'age']].head()
# Out:
#    model_id  entity_id  score  label_value race gender  age
# 0         1          1      1            1    W      M    3
# 1         1          2      1            0    B      M    3
# 2         1          3      1            1    B      F    2
# 3         1          4      1            1    W      M    1
# 4         1          5      1            0    B      M    4

# %% [markdown]
# ### Output
# `aequitas_audit` returns multiple levels of analysis. We will start looking at supervised fairness at the group level.
#
# #### Group-level 'supervised fairness'
#
# Supervised fairness is comprised of Type I and Type II errors familar from statistics. In machine learning, these are captured by the False Discovery Rate or False Positive Rate (Type I) and False Ommision Rate or False Negative Rate (Type II).
#
# A model is considered to display "supervised fairness" if disparity ratios of the above statistics fall within an acceptable range.
#
# $$ Disparity =  \frac{metric_{group}}{metric_{base group}} $$
# For details [link to more documentation].

# %%
df.head()
# Out:
#    model_id  entity_id  score  rank_abs  rank_pct  label_value race gender  \
# 0         1          1      1         1      0.05            1    W      M
# 1         1          2      1         2      0.10            0    B      M
# 2         1          3      1         3      0.15            1    B      F
# 3         1          4      1         4      0.20            1    W      M
# 4         1          5      1         5      0.25            0    B      M
#
#    age
# 0    3
# 1    3
# 2    2
# 3    1
# 4    4

# %%
df = pd.read_csv('../data/compas_group_value_fairness.csv')
df[['group_value', 'group_variable', 'Supervised Fairness']].style.applymap(color_tf)
# Out:
# <style  type="text/css" >
#     #T_f97734e6_3374_11e8_b715_a0999b0ab569row0_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row0_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row0_col2 {
#             color:  red;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row1_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row1_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row1_col2 {
#             color:  red;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row2_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row2_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row2_col2 {
#             color:  green;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row3_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row3_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row3_col2 {
#             color:  green;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row4_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row4_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row4_col2 {
#             color:  red;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row5_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row5_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row5_col2 {
#             color:  red;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row6_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row6_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row6_col2 {
#             color:  red;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row7_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row7_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row7_col2 {
#             color:  green;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row8_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row8_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row8_col2 {
#             color:  green;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row9_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row9_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row9_col2 {
#             color:  red;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row10_col0 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row10_col1 {
#             color:  ;
#         }    #T_f97734e6_3374_11e8_b715_a0999b0ab569row10_col2 {
#             color:  red;
#         }</style>
# <table id="T_f97734e6_3374_11e8_b715_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >group_value</th>
#         <th class="col_heading level0 col1" >group_variable</th>
#         <th class="col_heading level0 col2" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row0_col0" class="data row0 col0" >African-American</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row0_col1" class="data row0 col1" >race</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row0_col2" class="data row0 col2" >False</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row1_col0" class="data row1 col0" >Asian</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row1_col1" class="data row1 col1" >race</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row1_col2" class="data row1 col2" >False</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row2_col0" class="data row2 col0" >Caucasian</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row2_col1" class="data row2 col1" >race</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row2_col2" class="data row2 col2" >True</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row3_col0" class="data row3 col0" >Hispanic</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row3_col1" class="data row3 col1" >race</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row3_col2" class="data row3 col2" >True</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row4_col0" class="data row4 col0" >Native American</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row4_col1" class="data row4 col1" >race</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row4_col2" class="data row4 col2" >False</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row5_col0" class="data row5 col0" >Other</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row5_col1" class="data row5 col1" >race</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row5_col2" class="data row5 col2" >False</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row6_col0" class="data row6 col0" >Female</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row6_col1" class="data row6 col1" >sex</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row6_col2" class="data row6 col2" >False</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row7_col0" class="data row7 col0" >Male</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row7_col1" class="data row7 col1" >sex</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row7_col2" class="data row7 col2" >True</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row8_col0" class="data row8 col0" >25 - 45</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row8_col1" class="data row8 col1" >age_cat</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row8_col2" class="data row8 col2" >True</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row9_col0" class="data row9 col0" >Greater than 45</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row9_col1" class="data row9 col1" >age_cat</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row9_col2" class="data row9 col2" >False</td>
#     </tr>    <tr>
#         <th id="T_f97734e6_3374_11e8_b715_a0999b0ab569level0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row10_col0" class="data row10 col0" >Less than 25</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row10_col1" class="data row10 col1" >age_cat</td>
#         <td id="T_f97734e6_3374_11e8_b715_a0999b0ab569row10_col2" class="data

# %% [markdown]
# In this case, our base groups are Caucasian for race, Male for gender, and 25-45 for age_cat. By construction, the base group has supervised fairness. (The disparity ratio is 1). Relative to the base groups, the COMPAS predictions only provide supervised fairness to one group, Hispanic.
#
# To understand these results, we will look at the underlying metrics.

# %%
race_df = df[['group_value', 'group_variable', 'FOmR', 'FDR', 'FPR', 'FNR']]\
        .query("group_variable == 'race'")
race_df.loc[df.index.max() + 1] = ["normalizer","normalizer", 1, 1,1,1]
race_df = race_df.style.set_properties(**{'border-style':'solid', 'border-color': 'white'})\
        .bar(subset=['FDR', 'FOmR', 'FPR', 'FNR'], align='mid', color='#4682B4')
    
race_df

# As far as I can tell, there is not a built in way to have normalized bar lengths without 
# the inclusion of a row of 1s.
# e.g.
# race_df.data.drop(axis=0, index=11, inplace=True)

# pandas.io.formats.style.Styler
# Out:
# <style  type="text/css" >
#     #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row0_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row0_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row0_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 35.0%, transparent 35.0%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row0_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 37.0%, transparent 37.0%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row0_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 44.8%, transparent 44.8%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row0_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 28.0%, transparent 28.0%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row1_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row1_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row1_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 12.5%, transparent 12.5%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row1_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.0%, transparent 25.0%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row1_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 8.7%, transparent 8.7%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row1_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 33.3%, transparent 33.3%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row2_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row2_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row2_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 28.8%, transparent 28.8%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row2_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 40.9%, transparent 40.9%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row2_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 23.5%, transparent 23.5%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row2_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 47.7%, transparent 47.7%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row3_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row3_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row3_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 28.9%, transparent 28.9%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row3_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 45.8%, transparent 45.8%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row3_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 21.5%, transparent 21.5%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row3_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 55.6%, transparent 55.6%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row4_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row4_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row4_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 16.7%, transparent 16.7%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row4_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.0%, transparent 25.0%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row4_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 37.5%, transparent 37.5%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row4_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 10.0%, transparent 10.0%);
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row5_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row5_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_a523aff4_3444_11e8_9a0e_a0999b0ab569row5_col2 {
#             borde

# %% [markdown]
# By default Aequitas says a metric is fair for a group if the group rate is within 25% of the base group. Above, the African-American false omission and false discovery are within the bounds of fairness. This result is expected because COMPAS is calibrated. (Given calibration, it is surprising that Asian and Native American rates are so low. This may be a matter of having few observations for these groups.)
#
# On the other hand, African-Americans are roughly twice as likely to have false positives and 40 percent less likely to false negatives. In real terms, 44.8% of African-Americans who did not recidivate were marked high or medium risk (with potential for associated penalties), compared with 23.4% of Caucasian non-reoffenders. This is unfair and is marked False below.

# %%
df[['group_value', 'group_variable', 'FOmR Parity','FDR Parity',  'FPR Parity',
       'FNR Parity', 'Supervised Fairness']].query("group_variable == 'race'").style.applymap(color_tf)
# Out:
# <style  type="text/css" >
#     #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col0 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col1 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col2 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col3 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col4 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col5 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col6 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col0 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col1 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col2 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col3 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col4 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col5 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col6 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col0 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col1 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col2 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col3 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col4 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col5 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col6 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col0 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col1 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col2 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col3 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col4 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col5 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col6 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col0 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col1 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col2 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col3 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col4 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col5 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col6 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col0 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col1 {
#             color:  ;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col2 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col3 {
#             color:  green;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col4 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col5 {
#             color:  red;
#         }    #T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row5_col6 {
#             color:  red;
#         }</style>
# <table id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >group_value</th>
#         <th class="col_heading level0 col1" >group_variable</th>
#         <th class="col_heading level0 col2" >FOmR Parity</th>
#         <th class="col_heading level0 col3" >FDR Parity</th>
#         <th class="col_heading level0 col4" >FPR Parity</th>
#         <th class="col_heading level0 col5" >FNR Parity</th>
#         <th class="col_heading level0 col6" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col0" class="data row0 col0" >African-American</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col1" class="data row0 col1" >race</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col2" class="data row0 col2" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col3" class="data row0 col3" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col4" class="data row0 col4" >False</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col5" class="data row0 col5" >False</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row0_col6" class="data row0 col6" >False</td>
#     </tr>    <tr>
#         <th id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col0" class="data row1 col0" >Asian</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col1" class="data row1 col1" >race</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col2" class="data row1 col2" >False</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col3" class="data row1 col3" >False</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col4" class="data row1 col4" >False</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col5" class="data row1 col5" >False</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row1_col6" class="data row1 col6" >False</td>
#     </tr>    <tr>
#         <th id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col0" class="data row2 col0" >Caucasian</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col1" class="data row2 col1" >race</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col2" class="data row2 col2" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col3" class="data row2 col3" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col4" class="data row2 col4" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col5" class="data row2 col5" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row2_col6" class="data row2 col6" >True</td>
#     </tr>    <tr>
#         <th id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col0" class="data row3 col0" >Hispanic</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col1" class="data row3 col1" >race</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col2" class="data row3 col2" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col3" class="data row3 col3" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col4" class="data row3 col4" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col5" class="data row3 col5" >True</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row3_col6" class="data row3 col6" >True</td>
#     </tr>    <tr>
#         <th id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col0" class="data row4 col0" >Native American</td>
#         <td id="T_28d4102e_2ede_11e8_9e6c_a0999b0ab569row4_col1" class="data ro

# %% [markdown]
# When comparing metrics by sex, COMPAS data fails fairness due to FOmR and FDR for female defenants on account of false omission and false discovery.

# %%
sex_df = df[['group_value', 'group_variable', 'FOmR', 'FDR', 'FPR', 'FNR']]\
        .query("group_variable == 'sex'")#, \
sex_df.loc[df.index.max() + 1] = ["normalizer","normalizer", 1, 1,1,1]
sex_df = sex_df.style.set_properties(**{'border-style':'solid', 'border-color': 'white'})\
        .bar(subset=['FDR', 'FOmR', 'FPR', 'FNR'], align='mid', color='#4682B4')
    
sex_df
# Out:
# <style  type="text/css" >
#     #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 24.3%, transparent 24.3%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 48.7%, transparent 48.7%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 32.1%, transparent 32.1%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 39.2%, transparent 39.2%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 33.0%, transparent 33.0%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 36.5%, transparent 36.5%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 32.4%, transparent 32.4%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 37.1%, transparent 37.1%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 100.0%, transparent 100.0%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 100.0%, transparent 100.0%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 100.0%, transparent 100.0%);
#         }    #T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 100.0%, transparent 100.0%);
#         }</style>
# <table id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >group_value</th>
#         <th class="col_heading level0 col1" >group_variable</th>
#         <th class="col_heading level0 col2" >FOmR</th>
#         <th class="col_heading level0 col3" >FDR</th>
#         <th class="col_heading level0 col4" >FPR</th>
#         <th class="col_heading level0 col5" >FNR</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569level0_row0" class="row_heading level0 row0" >6</th>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col0" class="data row0 col0" >Female</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col1" class="data row0 col1" >sex</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col2" class="data row0 col2" >0.242537</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col3" class="data row0 col3" >0.48731</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col4" class="data row0 col4" >0.32107</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row0_col5" class="data row0 col5" >0.391566</td>
#     </tr>    <tr>
#         <th id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569level0_row1" class="row_heading level0 row1" >7</th>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col0" class="data row1 col0" >Male</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col1" class="data row1 col1" >sex</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col2" class="data row1 col2" >0.3301</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col3" class="data row1 col3" >0.364637</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col4" class="data row1 col4" >0.324201</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row1_col5" class="data row1 col5" >0.370868</td>
#     </tr>    <tr>
#         <th id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569level0_row2" class="row_heading level0 row2" >11</th>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col0" class="data row2 col0" >normalizer</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col1" class="data row2 col1" >normalizer</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col2" class="data row2 col2" >1</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col3" class="data row2 col3" >1</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col4" class="data row2 col4" >1</td>
#         <td id="T_28e869ac_2ede_11e8_b63c_a0999b0ab569row2_col5" class="data row2 col5" >1</td>
#     </tr></tbody>
# </table>

# %%
df[['group_value', 'group_variable', 'FOmR Parity','FDR Parity',  'FPR Parity',
       'FNR Parity', 'Supervised Fairness']].query("group_variable == 'sex'").style.applymap(color_tf)
# Out:
# <style  type="text/css" >
#     #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col0 {
#             color:  ;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col1 {
#             color:  ;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col2 {
#             color:  red;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col3 {
#             color:  red;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col4 {
#             color:  green;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col5 {
#             color:  green;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col6 {
#             color:  red;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col0 {
#             color:  ;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col1 {
#             color:  ;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col2 {
#             color:  green;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col3 {
#             color:  green;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col4 {
#             color:  green;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col5 {
#             color:  green;
#         }    #T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col6 {
#             color:  green;
#         }</style>
# <table id="T_28ee9462_2ede_11e8_a438_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >group_value</th>
#         <th class="col_heading level0 col1" >group_variable</th>
#         <th class="col_heading level0 col2" >FOmR Parity</th>
#         <th class="col_heading level0 col3" >FDR Parity</th>
#         <th class="col_heading level0 col4" >FPR Parity</th>
#         <th class="col_heading level0 col5" >FNR Parity</th>
#         <th class="col_heading level0 col6" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_28ee9462_2ede_11e8_a438_a0999b0ab569level0_row0" class="row_heading level0 row0" >6</th>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col0" class="data row0 col0" >Female</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col1" class="data row0 col1" >sex</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col2" class="data row0 col2" >False</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col3" class="data row0 col3" >False</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col4" class="data row0 col4" >True</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col5" class="data row0 col5" >True</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row0_col6" class="data row0 col6" >False</td>
#     </tr>    <tr>
#         <th id="T_28ee9462_2ede_11e8_a438_a0999b0ab569level0_row1" class="row_heading level0 row1" >7</th>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col0" class="data row1 col0" >Male</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col1" class="data row1 col1" >sex</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col2" class="data row1 col2" >True</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col3" class="data row1 col3" >True</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col4" class="data row1 col4" >True</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col5" class="data row1 col5" >True</td>
#         <td id="T_28ee9462_2ede_11e8_a438_a0999b0ab569row1_col6" class="data row1 col6" >True</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Group-level unsupervised fairness
#
# TEXT TO FOLLOW

# %%
df_uf = df[['group_value', 'group_variable','PPR', 'PPrev','Statistical Parity','Impact Parity','Unsupervised Fairness']]\
        
df_uf.loc[df.index.max() + 1] = ["normalizer","normalizer", 1, 1, "","",""]

df_uf.style.applymap(color_tf)\
     .set_properties(**{'border-style':'solid', 'border-color': 'white', 'white-space': 'nowrap'})\
     .bar(subset=['PPR', 'PPrev'], align='mid', color='#4682B4')
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <style  type="text/css" >
#     #T_68304606_3119_11e8_b753_a0999b0ab569row0_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row0_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row0_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 65.5%, transparent 65.5%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row0_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 58.8%, transparent 58.8%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row0_col4 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row0_col5 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row0_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 0.2%, transparent 0.2%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.0%, transparent 25.0%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col4 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col5 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row1_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.7%, transparent 25.7%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 34.8%, transparent 34.8%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col4 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col5 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row2_col6 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 5.7%, transparent 5.7%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 29.8%, transparent 29.8%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col4 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col5 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row3_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row4_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row4_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row4_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 0.4%, transparent 0.4%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row4_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 66.7%, transparent 66.7%);
#         }    #T_68304606_3119_11e8_b753_a0999b0ab569row4_col4 {
#             color:  red;

# %% [markdown]
# ### Group Variable Fairness
#
# When there are many groups it is useful to have a broader overview of fairness. Aequitas summarizes parity and fairness for "group variables" (e.g. race, sex, age category). Similar to above, we report True if all parity measures of the subgroups are True. For example, below we see that Impact Parity is True for sex, this implies Impact Parity is fair for male and female (which can be verified above).

# %%
group_var_df = pd.read_csv('../data/compas_group_variable_fairness.csv',index_col=0)
display(group_var_df.style.applymap(color_tf))
# Out:
# <style  type="text/css" >
#     #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col0 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col1 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col2 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col3 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col4 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col5 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col6 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col7 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col8 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col9 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col10 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col11 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col0 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col1 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col2 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col3 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col4 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col5 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col6 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col7 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col8 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col9 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col10 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col11 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col0 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col1 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col2 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col3 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col4 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col5 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col6 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col7 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col8 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col9 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col10 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col11 {
#             color:  red;
#         }</style>
# <table id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >model_id</th>
#         <th class="col_heading level0 col1" >parameter</th>
#         <th class="col_heading level0 col2" >group_variable</th>
#         <th class="col_heading level0 col3" >Impact Parity</th>
#         <th class="col_heading level0 col4" >FDR Parity</th>
#         <th class="col_heading level0 col5" >FPR Parity</th>
#         <th class="col_heading level0 col6" >FOmR Parity</th>
#         <th class="col_heading level0 col7" >FNR Parity</th>
#         <th class="col_heading level0 col8" >TypeI Parity</th>
#         <th class="col_heading level0 col9" >TypeII Parity</th>
#         <th class="col_heading level0 col10" >Unsupervised Fairness</th>
#         <th class="col_heading level0 col11" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col0" class="data row0 col0" >1</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col1" class="data row0 col1" >3317_abs</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col2" class="data row0 col2" >age_cat</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col3" class="data row0 col3" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col4" class="data row0 col4" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col5" class="data row0 col5" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col6" class="data row0 col6" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col7" class="data row0 col7" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col8" class="data row0 col8" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col9" class="data row0 col9" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col10" class="data row0 col10" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col11" class="data row0 col11" >False</td>
#     </tr>    <tr>
#         <th id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col0" class="data row1 col0" >1</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col1" class="data row1 col1" >3317_abs</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col2" class="data row1 col2" >race</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col3" class="data row1 col3" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col4" class="data row1 col4" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col5" class="data row1 col5" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col6" class="data row1 col6" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col7" class="data row1 col7" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col8" class="data row1 col8" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col9" class="data row1 col9" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col10" class="data row1 col10" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col11" class="data row1 col11" >False</td>
#     </tr>    <tr>
#         <th id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col0" class="data row2 col0" >1</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col1" class="data row2 col1" >3317_abs</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col2" class="data row2 col2" >sex</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col3" class="data row2 col3" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col4" class="data row2 col4" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col5" class="data row2 col5" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col6" class="data row2 col6" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col7" class="data row2 col7" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col8" class="data row2 col8" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col9" class="data row2 col9" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_

# %% [markdown]
# SHOULD WE SAY SOMETHING LIKE ...
# The more subgroups under a "group variable" the more likely a parity measure will be false. As we saw above, despite calibration, . The user should consider how sample size impacts their analysis and consider adjusting data accordingly.
