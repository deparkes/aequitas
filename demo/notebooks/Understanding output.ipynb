# %% [markdown]
# # Understanding Output
#
# Here we provide a highlevel overview of the bias and fairness metrics output by Aequitas. For detailed definitions of the metrics see [Understanding our metrics]()

# %%
import pandas as pd

def color_tf(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    if val == True:
        color = 'green'
    elif val == False:
        color = 'red'
    else:
        color = ''
    return 'color: %s' % color

# %%
df = pd.read_csv('../data/aequinas_test_20180223.csv')

# %% [markdown]
# ### Input data
#
# You input a csv using the command-line function `aequitas_audit`. The csv has columns for `entity_id`, `score`, and `label_value` as well as group attributes against which to test for disparities. In this cases we include `race`, `sex` and `age_cat`. This data comes from [this ProPublica analysis](https://github.com/propublica/compas-analysis) of the Northpoint COMPAS risk assessment algorithm.

# %%
df[['model_id', 'entity_id', 'score', 'label_value','race', 'gender', 'age']].head()
# Out:
#    model_id  entity_id  score  label_value race gender  age
# 0         1          1      1            1    W      M    3
# 1         1          2      1            0    B      M    3
# 2         1          3      1            1    B      F    2
# 3         1          4      1            1    W      M    1
# 4         1          5      1            0    B      M    4

# %% [markdown]
# ## Output
# `aequitas_audit` returns multiple levels of analysis. Bias metrics, such as False Omission Rate, False Discovery Rate, False Positive Rate and False Negative Rate, look at individual groups.
#
# ---
# ### Bias measures

# %%
# load aequitas output
full_df = pd.read_csv('../data/compas_group_value_fairness.csv')

# filter to focus on race and bias metrics
df = full_df[['group_value', 'group_variable', 'FOmR', 'FDR', 'FPR', 'FNR']]\
                .query("group_variable == 'race'")

# stylize for nice presentation        
df.loc[df.index.max() + 1] = ["normalizer","normalizer", 1, 1,1,1]
df = df.style.set_properties(**{'border-style':'solid', 'border-color': 'white'})\
        .bar(subset=['FDR', 'FOmR', 'FPR', 'FNR'], align='mid', color='#4682B4')
    
display(df)

# As far as I can tell, there is not a built in way to have normalized bar lengths without 
# the inclusion of a row of 1s.
# e.g.
# df.data.drop(axis=0, index=11, inplace=True)
# pandas.io.formats.style.Styler also does not seem to appear on github. Will investigate al
# Out:
# <style  type="text/css" >
#     #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row0_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row0_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row0_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 35.0%, transparent 35.0%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row0_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 37.0%, transparent 37.0%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row0_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 44.8%, transparent 44.8%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row0_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 28.0%, transparent 28.0%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row1_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row1_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row1_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 12.5%, transparent 12.5%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row1_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.0%, transparent 25.0%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row1_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 8.7%, transparent 8.7%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row1_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 33.3%, transparent 33.3%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row2_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row2_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row2_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 28.8%, transparent 28.8%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row2_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 40.9%, transparent 40.9%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row2_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 23.5%, transparent 23.5%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row2_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 47.7%, transparent 47.7%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row3_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row3_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row3_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 28.9%, transparent 28.9%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row3_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 45.8%, transparent 45.8%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row3_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 21.5%, transparent 21.5%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row3_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 55.6%, transparent 55.6%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row4_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row4_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row4_col2 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 16.7%, transparent 16.7%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row4_col3 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.0%, transparent 25.0%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row4_col4 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 37.5%, transparent 37.5%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row4_col5 {
#             border-style:  solid;
#             border-color:  white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 10.0%, transparent 10.0%);
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row5_col0 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row5_col1 {
#             border-style:  solid;
#             border-color:  white;
#         }    #T_ecb7b4ee_344e_11e8_93e4_a0999b0ab569row5_col2 {
#             borde

# %% [markdown]
# ### Disparity measures
#
# Disparity are measured in relation to a base group (see [defining a base group]())
#
# $$ Disparity =  \frac{metric_{group}}{metric_{base group}} $$
#
# For details [link to more documentation].

# %%
full_df[['group_value', 'group_variable', 'FDR_disparity', 'FOmR_disparity',
       'FPR_disparity', 'FNR_disparity', 'Supervised Fairness']].query("group_variable == 'race'").style.applymap(color_tf)\
             .set_properties(**{'border-style':'solid', 'border-color': 'white'})\
# bars can't be normalized so are confusing.
# Out:
# <style  type="text/css" >
#     #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row1_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col2 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col3 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col4 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col5 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row2_col6 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row3_col6 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row4_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#         }    #T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row5_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#         }</style>
# <table id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >group_value</th>
#         <th class="col_heading level0 col1" >group_variable</th>
#         <th class="col_heading level0 col2" >FDR_disparity</th>
#         <th class="col_heading level0 col3" >FOmR_disparity</th>
#         <th class="col_heading level0 col4" >FPR_disparity</th>
#         <th class="col_heading level0 col5" >FNR_disparity</th>
#         <th class="col_heading level0 col6" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col0" class="data row0 col0" >African-American</td>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col1" class="data row0 col1" >race</td>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col2" class="data row0 col2" >0.906085</td>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col3" class="data row0 col3" >1.21315</td>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col4" class="data row0 col4" >1.91209</td>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col5" class="data row0 col5" >0.586416</td>
#         <td id="T_d4fcc1d2_3453_11e8_b27f_a0999b0ab569row0_col6" class="data row0 col6" >False</td>
#     </tr>

# %% [markdown]
# ### Group-level fairness
#
# By default, Aequitas says a metric is fair for a group if the group rate is within X% of the base group.
#
# Supervised fairness is comprised of Type I and Type II errors familar from statistics. In machine learning, these are captured by the False Discovery Rate or False Positive Rate (Type I) and False Ommision Rate or False Negative Rate (Type II). Supervised Fairness is True for a group, if each of these metrics is within the bounds of fairness compared to the base group.

# %%
full_df[['group_value', 'group_variable', 'FOmR Parity','FDR Parity',  'FPR Parity',
       'FNR Parity', 'Supervised Fairness']].query("group_variable == 'race'").style.applymap(color_tf)
# Out:
# <style  type="text/css" >
#     #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col0 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col1 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col2 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col3 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col4 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col5 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col6 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col0 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col1 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col2 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col3 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col4 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col5 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col6 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col0 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col1 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col2 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col3 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col4 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col5 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col6 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col0 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col1 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col2 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col3 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col4 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col5 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col6 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col0 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col1 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col2 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col3 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col4 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col5 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col6 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col0 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col1 {
#             color:  ;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col2 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col3 {
#             color:  green;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col4 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col5 {
#             color:  red;
#         }    #T_f1a93648_344f_11e8_afbf_a0999b0ab569row5_col6 {
#             color:  red;
#         }</style>
# <table id="T_f1a93648_344f_11e8_afbf_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >group_value</th>
#         <th class="col_heading level0 col1" >group_variable</th>
#         <th class="col_heading level0 col2" >FOmR Parity</th>
#         <th class="col_heading level0 col3" >FDR Parity</th>
#         <th class="col_heading level0 col4" >FPR Parity</th>
#         <th class="col_heading level0 col5" >FNR Parity</th>
#         <th class="col_heading level0 col6" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f1a93648_344f_11e8_afbf_a0999b0ab569level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col0" class="data row0 col0" >African-American</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col1" class="data row0 col1" >race</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col2" class="data row0 col2" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col3" class="data row0 col3" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col4" class="data row0 col4" >False</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col5" class="data row0 col5" >False</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row0_col6" class="data row0 col6" >False</td>
#     </tr>    <tr>
#         <th id="T_f1a93648_344f_11e8_afbf_a0999b0ab569level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col0" class="data row1 col0" >Asian</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col1" class="data row1 col1" >race</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col2" class="data row1 col2" >False</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col3" class="data row1 col3" >False</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col4" class="data row1 col4" >False</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col5" class="data row1 col5" >False</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row1_col6" class="data row1 col6" >False</td>
#     </tr>    <tr>
#         <th id="T_f1a93648_344f_11e8_afbf_a0999b0ab569level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col0" class="data row2 col0" >Caucasian</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col1" class="data row2 col1" >race</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col2" class="data row2 col2" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col3" class="data row2 col3" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col4" class="data row2 col4" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col5" class="data row2 col5" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row2_col6" class="data row2 col6" >True</td>
#     </tr>    <tr>
#         <th id="T_f1a93648_344f_11e8_afbf_a0999b0ab569level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col0" class="data row3 col0" >Hispanic</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col1" class="data row3 col1" >race</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col2" class="data row3 col2" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col3" class="data row3 col3" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col4" class="data row3 col4" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col5" class="data row3 col5" >True</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row3_col6" class="data row3 col6" >True</td>
#     </tr>    <tr>
#         <th id="T_f1a93648_344f_11e8_afbf_a0999b0ab569level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col0" class="data row4 col0" >Native American</td>
#         <td id="T_f1a93648_344f_11e8_afbf_a0999b0ab569row4_col1" class="data ro

# %% [markdown]
# ### Group-level unsupervised fairness
#
# We can see the entire flow from group-level bias metrics to assertion of fairness using unsupervised fairness.
#
# < more description >

# %%
df_uf = full_df[['group_value', 'group_variable','PPR', 'PPrev','PPR_disparity', 'PPrev_disparity','Statistical Parity','Impact Parity','Unsupervised Fairness']]\
                .query("group_variable =='race'")
        
df_uf.loc[full_df.index.max() + 1] = ["normalizer","normalizer", 1, 1, "","","","",""]

df_uf.style.applymap(color_tf)\
     .set_properties(**{'border-style':'solid', 'border-color': 'white', 'white-space': 'nowrap'})\
     .bar(subset=['PPR', 'PPrev'], align='mid', color='#4682B4')
# Out:
# <style  type="text/css" >
#     #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 65.5%, transparent 65.5%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 58.8%, transparent 58.8%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col7 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row0_col8 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 0.2%, transparent 0.2%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.0%, transparent 25.0%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col7 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row1_col8 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 25.7%, transparent 25.7%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 34.8%, transparent 34.8%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col4 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col5 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col6 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col7 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row2_col8 {
#             color:  green;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col0 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col1 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col2 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 5.7%, transparent 5.7%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col3 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #4682B4 0.0%, #4682B4 29.8%, transparent 29.8%);
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col4 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col5 {
#             color:  ;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col6 {
#             color:  red;
#             border-style:  solid;
#             border-color:  white;
#             white-space:  nowrap;
#         }    #T_c71bf66c_3455_11e8_87e8_a0999b0ab569row3_col7 {
#             c

# %%
# Code for sex ... probably not necessary
sex_df = full_df[['group_value', 'group_variable', 'FOmR', 'FDR', 'FPR', 'FNR']]\
        .query("group_variable == 'sex'")#, \
sex_df.loc[df.index.max() + 1] = ["normalizer","normalizer", 1, 1,1,1]
sex_df = sex_df.style.set_properties(**{'border-style':'solid', 'border-color': 'white'})\
        .bar(subset=['FDR', 'FOmR', 'FPR', 'FNR'], align='mid', color='#4682B4')
    
sex_df

# %%
full_df[['group_value', 'group_variable', 'FOmR Parity','FDR Parity',  'FPR Parity',
       'FNR Parity', 'Supervised Fairness']].query("group_variable == 'sex'").style.applymap(color_tf)

# %% [markdown]
# ## Group Variable Fairness
#
# When there are many groups it is useful to have a broader overview of fairness. Aequitas summarizes parity and fairness for "group variables" (e.g. race, sex, age category). Similar to above, we report True if all parity measures of the subgroups are True. For example, below we see that Impact Parity is True for sex, this implies Impact Parity is fair for male and female (which can be verified above).

# %%
group_var_df = pd.read_csv('../data/compas_group_variable_fairness.csv',index_col=0)
display(group_var_df.style.applymap(color_tf))
# Out:
# <style  type="text/css" >
#     #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col0 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col1 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col2 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col3 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col4 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col5 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col6 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col7 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col8 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col9 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col10 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col11 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col0 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col1 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col2 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col3 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col4 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col5 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col6 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col7 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col8 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col9 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col10 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col11 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col0 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col1 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col2 {
#             color:  ;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col3 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col4 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col5 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col6 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col7 {
#             color:  green;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col8 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col9 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col10 {
#             color:  red;
#         }    #T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col11 {
#             color:  red;
#         }</style>
# <table id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >model_id</th>
#         <th class="col_heading level0 col1" >parameter</th>
#         <th class="col_heading level0 col2" >group_variable</th>
#         <th class="col_heading level0 col3" >Impact Parity</th>
#         <th class="col_heading level0 col4" >FDR Parity</th>
#         <th class="col_heading level0 col5" >FPR Parity</th>
#         <th class="col_heading level0 col6" >FOmR Parity</th>
#         <th class="col_heading level0 col7" >FNR Parity</th>
#         <th class="col_heading level0 col8" >TypeI Parity</th>
#         <th class="col_heading level0 col9" >TypeII Parity</th>
#         <th class="col_heading level0 col10" >Unsupervised Fairness</th>
#         <th class="col_heading level0 col11" >Supervised Fairness</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col0" class="data row0 col0" >1</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col1" class="data row0 col1" >3317_abs</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col2" class="data row0 col2" >age_cat</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col3" class="data row0 col3" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col4" class="data row0 col4" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col5" class="data row0 col5" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col6" class="data row0 col6" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col7" class="data row0 col7" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col8" class="data row0 col8" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col9" class="data row0 col9" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col10" class="data row0 col10" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row0_col11" class="data row0 col11" >False</td>
#     </tr>    <tr>
#         <th id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col0" class="data row1 col0" >1</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col1" class="data row1 col1" >3317_abs</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col2" class="data row1 col2" >race</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col3" class="data row1 col3" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col4" class="data row1 col4" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col5" class="data row1 col5" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col6" class="data row1 col6" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col7" class="data row1 col7" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col8" class="data row1 col8" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col9" class="data row1 col9" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col10" class="data row1 col10" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row1_col11" class="data row1 col11" >False</td>
#     </tr>    <tr>
#         <th id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col0" class="data row2 col0" >1</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col1" class="data row2 col1" >3317_abs</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col2" class="data row2 col2" >sex</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col3" class="data row2 col3" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col4" class="data row2 col4" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col5" class="data row2 col5" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col6" class="data row2 col6" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col7" class="data row2 col7" >True</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col8" class="data row2 col8" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_87c9_a0999b0ab569row2_col9" class="data row2 col9" >False</td>
#         <td id="T_dbbb02e2_3115_11e8_
